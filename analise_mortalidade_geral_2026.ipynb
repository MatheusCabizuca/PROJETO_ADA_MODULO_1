# %%
##importação das bibliotecas
import pandas as pd
import numpy as np

# %% [markdown]
# **Código de importação da base - Mariana/Matheus/Marcos**
#
#   Cada um altera o caminho do documento quando for trabalhar no notebook, para manter o mesmo nome da variável
#
#   r"C:\Users\c121733\OneDrive - Caixa Economica Federal\Área de Trabalho\CURSO_CIENTISTA_DE_DADOS_ADA\PROJETO ADA - 1 MODULO\PROJETO_GIT\MORTALIDADE_GERAL_2026.csv" (copiar como caminho)

# %%
mortalidade = pd.read_csv(r"C:\Users\c121733\OneDrive - Caixa Economica Federal\Área de Trabalho\CURSO_CIENTISTA_DE_DADOS_ADA\PROJETO ADA - 1 MODULO\PROJETO_GIT\MORTALIDADE_GERAL_2026.csv", sep=';',parse_dates=['DTOBITO', 'DTNASC'])

# %%
mortalidade.head()

# %% [markdown]
# **Definição dos questionamentos a serem respondidos, para criar um dataframe somente com as colunas a serem utilizadas**
#
# 1 - QUANTIDADE DE MORTES POR MÊS
#
# 2 - MÉDIA, MEDIANA, DESVIO PADRÃO DE IDADE POR MÊS
#
# 3 - QUANTITATIVO DE MORTES POR ESTADO, NO SEMESTRE
#
# 4 - QUANTITATIVO DE MORTES POR CID
#
# 5 - QUANTITATIVO DE MORTES DAS 10 MAIORES CAUSAS, E PERCENTUAL
#
# 6 - QUANTITATIVO DE MORTES POR FAIXA DE IDADE (SUGIRO 4 OU 5 FAIXAS - ATÉ 2 ANOS, < 10, <20, <60, >= 60)
#
# 7 - 10 CIDADES QUE MAIS MORRERAM PESSOAS
#
# 8 - TRAZER A POPULAÇÃO DE CADA CIDADE, PARA MOSTRAR O PERCENTUAL DE OBITOS POR POPULAÇÃO (MOSTRAR AS CIDADES    QUE MAIS MORRERAM PROPORCIONALMENTE)
#
# 9 - IQR DA COLUNA IDADE, HISTOGRAMA POR FAIXA DE IDADE, CURVA DE DISTRIBUIÇÃO, COLUNA DE Z-SCORE

# %%
mortalidade.info()
#SUGESTÃO DE COLUNAS
#CONTADOR (INDICE), DTOBITO, CODMUNNATU (CIDADE DE NASCIMENTO),DTNASC, IDADE, 
# SEXO, CODMUNOCOR (CIDADE DO ÓBITO), CAUSABAS (CAUSA DA MORTE), NECROPSIA

# %% [markdown]
# **LIMPEZA DA BASE (EXCLUSÃO DE COLUNAS) E CRIAÇÃO DE COLUNAS DERIVADAS**
#
# CRIAR COLUNA PADRONIZADA DE IDADE, TRAZER NOME DO MUNICÍPIO, ESTADO E POPULAÇÃO, NOME DA DOENÇA CORRESPONDENTE À CID
#
# CRUZAR COM AS TABELAS DE MUNICÍPIO E CID

# %% [markdown]
# **ANÁLISES E GRÁFICOS**

# %% [markdown]
# **ACHADOS E CONCLUSÕES**
